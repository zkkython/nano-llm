# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import torch

# %%
a = torch.randn((2,2))
a
# Out:
# tensor([[-0.6282,  0.5124],
#         [ 1.0945,  1.0853]])

# %%
a.T
# Out:
# tensor([[-0.6282,  1.0945],
#         [ 0.5124,  1.0853]])
